# %% [markdown]
# Read John Hopkins data

# %%
import numpy as np
import datetime
import pandas as pd
from datetime import timedelta, date
pathJH='/Users/julia/Documents/Project/'

# %%
todayDate= datetime.datetime.strptime('20/03/23', "%y/%m/%d")
startDate= datetime.datetime.strptime('20/01/22', "%y/%m/%d")
diffDates= (todayDate - startDate).days

# %%
df=pd.read_csv(pathJH+'JohnHopkins/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv')
df['Last Update']=pd.to_datetime(df['Last Update'], format='%m/%d/%Y %H:%M')
for i in range(1,11):
    curDate=startDate+timedelta(days=i)
    df_temp=pd.read_csv(pathJH+'JohnHopkins/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/'+
                str(curDate.month).zfill(2)+'-'+str(curDate.day).zfill(2)+'-'+str(curDate.year)+'.csv')
    #print(df_temp)
    df_temp['Last Update']=df_temp['Last Update'].replace({'2020':'20'}, regex=True)
    df_temp['Last Update']=df_temp['Last Update'].replace({'20T':'20 '}, regex=True)

    df_temp['Last Update']=pd.to_datetime(df_temp['Last Update'], format='%m/%d/%y %H:%M')
    df=df.append(df_temp,ignore_index=True)

for i in range(11,diffDates):
    curDate=startDate+timedelta(days=i)
    df_temp=pd.read_csv(pathJH+'JohnHopkins/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/'+
                str(curDate.month).zfill(2)+'-'+str(curDate.day).zfill(2)+'-'+str(curDate.year)+'.csv')
    #print(df_temp)
    #df_temp['Last Update']=df_temp['Last Update'].replace({'2020':'20'}, regex=True)
    #df_temp['Last Update']=df_temp['Last Update'].replace({'20T':'20 '}, regex=True)

    df_temp['Last Update']=pd.to_datetime(df_temp['Last Update'], format='%Y-%m-%dT%H:%M')
    df=df.append(df_temp,ignore_index=True)

# %%
df.to_csv(pathJH+'Cor/data_new.csv',index=False)

# %%
df.head(10)
# Out:
#    Confirmed  Country/Region  Deaths         Last Update  Latitude  Longitude  \
# 0        1.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 1       14.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 2        6.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 3        1.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 4        NaN  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 5       26.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 6        2.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 7        1.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 8        4.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
# 9        1.0  Mainland China     NaN 2020-01-22 17:00:00       NaN        NaN
#
#   Province/State  Recovered
# 0          Anhui        NaN
# 1        Beijing        NaN
# 2      Chongqing        NaN
# 3         Fujian        NaN
# 4          Gansu        NaN
# 5      Guangdong        NaN
# 6        Guangxi        NaN
# 7        Guizhou        NaN
# 8         Hainan        NaN
# 9          Hebei        NaN
